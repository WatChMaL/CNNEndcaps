# %%
import os
mu_p = "/home/dyl055/projects/rpp-tanaka-ab/machine_learning/data/IWCDmPMT_4pi_full_tank/numpy_new/mu-/E0to1000MeV/unif-pos-R371-y521cm/4pi-dir/IWCDmPMT_4pi_full_tank_mu-_E0to1000MeV_unif-pos-R371-y521cm_4pi-dir_3000evts_"
e_p = "/home/dyl055/projects/rpp-tanaka-ab/machine_learning/data/IWCDmPMT_4pi_full_tank/numpy_new/e-/E0to1000MeV/unif-pos-R371-y521cm/4pi-dir/IWCDmPMT_4pi_full_tank_e-_E0to1000MeV_unif-pos-R371-y521cm_4pi-dir_3000evts_"
gamma_p = "/home/dyl055/projects/rpp-tanaka-ab/machine_learning/data/IWCDmPMT_4pi_full_tank/numpy_new/gamma/E0to1000MeV/unif-pos-R371-y521cm/4pi-dir/IWCDmPMT_4pi_full_tank_gamma_E0to1000MeV_unif-pos-R371-y521cm_4pi-dir_3000evts_"
filename = "filenames_all.txt"
with open(filename, "w") as f:
    for i in range(1000):
        mu_path = mu_p+str(i) + ".npz"
        e_path = e_p+str(i) + ".npz"
        gamma_path = gamma_p+str(i) + ".npz"
        if not os.path.exists(mu_path):
            print("No mu path " + str(i))
        if not os.path.exists(e_path):
            print("No e path " + str(i))
        if not os.path.exists(gamma_path):
            print("No gamma path " + str(i))
        f.write(mu_path+"\n")
        f.write(e_path + "\n")
        f.write(gamma_path+"\n")
# Out:
# No mu path 1000
# No e path 1000
# No gamma path 1000
# No mu path 1001
# No e path 1001
# No gamma path 1001
# No mu path 1002
# No e path 1002
# No gamma path 1002
# No mu path 1003
# No e path 1003
# No gamma path 1003
# No mu path 1004
# No e path 1004
# No gamma path 1004
# No mu path 1005
# No e path 1005
# No gamma path 1005
# No mu path 1006
# No e path 1006
# No gamma path 1006
# No mu path 1007
# No e path 1007
# No gamma path 1007
# No mu path 1008
# No e path 1008
# No gamma path 1008
# No mu path 1009
# No e path 1009
# No gamma path 1009
# No mu path 1010
# No e path 1010
# No gamma path 1010
# No mu path 1011
# No e path 1011
# No gamma path 1011
# No mu path 1012
# No e path 1012
# No gamma path 1012
# No mu path 1013
# No e path 1013
# No gamma path 1013
# No mu path 1014
# No e path 1014
# No gamma path 1014
# No mu path 1015
# No e path 1015
# No gamma path 1015
# No mu path 1016
# No e path 1016
# No gamma path 1016
# No mu path 1017
# No e path 1017
# ...

# %%
with open(filename, "r") as f:
    for i, l in enumerate(f):
            pass
    print(i + 1)
# Out:
# 7710
